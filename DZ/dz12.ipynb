# %%
# 1. Прочитайте все данные о продажах продукта и покажите их с помощью многострочного графика
# 2. Прочитайте данные о продажах мыла для купания за все месяцы и покажите их с помощью столбчатой диаграммы.
# 3. Рассчитайте общие данные о продажах за прошлый год для каждого продукта и покажите их с помощью круговой диаграммы

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

root = os.getcwd()
filename = os.path.join(root,'csd.csv')
data = pd.read_csv(filename)
data#.head()
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
head_list = ['month_number','facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer','total_units','total_profit']
k = 0
for i in head_list:
    head_list[k] = [i,data[i].tolist()]
    k += 1

# %%
for i in range(1,k-2):
    plt.plot((head_list[0])[1], (head_list[i])[1],linewidth=3, label=(head_list[i])[0], marker='o' )
plt.legend(loc='upper left')
plt.title('Продажи по месяцам')
plt.xlabel('месяцы')
plt.ylabel('Продано')
plt.xticks((head_list[0])[1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bathingsoap = data['bathingsoap'].tolist()
plt.grid(linewidth=1, linestyle='--')
plt.bar((head_list[0])[1],bathingsoap,label = 'bathingsoap', align = 'center')
plt.legend(loc='upper left')
plt.title('продажи мыла для купания')
plt.xlabel('месяцы')
plt.ylabel('Продажи')
plt.xticks((head_list[0])[1])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Продажи за год по продуктам')
labels = [ (head_list[i])[0] for i in range(1,len(head_list)-2)]
sizes = [ sum((head_list[i])[1]) for i in range(1,len(head_list)-2)]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')  
plt.show()
# Out:
# Продажи за год по продуктам
